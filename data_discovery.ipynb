# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
df_year_raw = pd.read_csv("data\\raw\\mlsruod_yearly.csv", index_col="date", parse_dates=["date"])
df_month_raw = pd.read_csv("data\\raw\\mlsruod_monthly.csv", index_col="date", parse_dates=["date"])

# %%
df_year = pd.read_csv("data\\preprocessed\\data_yearly.csv", index_col="date", parse_dates=["date"])
# df_month = pd.read_csv("data\\preprocessed\\data_monthly.csv")

# %%
print(df_year.head(5))
# Out:
#          date      f_rf  f_ind_M10_P  f_ind_M15_P  f_ind_M20_P  f_ind_M25_P  \
# 0  1996-01-31  1.497618    -0.637938    -0.552247    -0.471688    -0.405553
# 1  1996-02-29  1.658314    -0.500436    -0.560142    -0.573366    -0.527476
# 2  1996-03-29  1.752515    -0.733739    -0.650489    -0.572001    -0.507886
# 3  1996-04-30  1.863340    -0.782915    -0.701200    -0.626962    -0.571479
# 4  1996-05-31  1.935376    -0.616979    -0.532649    -0.460182    -0.427041
#
#    f_ind_M30_P  f_ind_M35_P  f_ind_M40_P  f_ind_M45_P  ...  \
# 0    -0.352648    -0.308701    -0.274255    -0.254251  ...
# 1    -0.479230    -0.436780    -0.397404    -0.352949  ...
# 2    -0.457682    -0.421190    -0.411957    -0.411960  ...
# 3    -0.525897    -0.484498    -0.442335    -0.380144  ...
# 4    -0.449833    -0.472186    -0.458540    -0.429135  ...
#
#    f_spxm_top_44_mcap  f_spxm_top_45_mcap  f_spxm_top_46_mcap  \
# 0           -1.599476           -1.584262           -1.578819
# ...

# %%
df_year.drop(df_year.columns[0], axis=1, inplace=True)
df_month.drop(df_month.columns[0], axis=1, inplace=True)

# %%
print(df_month.describe())
print(df_month.head(5))
# Out:
#                secid    theory_eret    target_eret           f_rf  \
# count  147446.000000  147446.000000  147446.000000  147446.000000
# mean   106726.804227       0.004960       0.008589       0.001664
# std     20471.978236       0.008045       0.102116       0.001684
# min      5015.000000      -0.009753      -0.983069       0.000000
# 25%    103406.000000       0.001375      -0.040569       0.000083
# 50%    106891.000000       0.002862       0.009091       0.001184
# 75%    110117.000000       0.005625       0.057509       0.003499
# max    214905.000000       0.364473       2.976153       0.005600
#
#          f_ind_M10_P    f_ind_M15_P    f_ind_M20_P    f_ind_M25_P  \
# count  147446.000000  147445.000000  147445.000000  147445.000000
# mean        0.429574       0.401263       0.377134       0.360318
# std         0.192478       0.185985       0.180846       0.176431
# min         0.032167       0.032167       0.032167       0.029099
# ...

# %%
df_month.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 147446 entries, 1996-01-31 to 2021-05-28
# Columns: 938 entries, secid to f_spxm_top_50_mcap
# dtypes: float64(937), int64(1)
# memory usage: 1.0 GB

# %%
print(df_year.info())
print(df_month.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 137831 entries, 1996-01-31 to 2020-06-30
# Columns: 938 entries, secid to f_spxm_top_50_mcap
# dtypes: float64(937), int64(1)
# memory usage: 987.4 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 147446 entries, 1996-01-31 to 2021-05-28
# Columns: 938 entries, secid to f_spxm_top_50_mcap
# dtypes: float64(937), int64(1)
# memory usage: 1.0 GB
# None

# %%
df_month.plot(y=["target_eret", "theory_eret"], use_index=True)

# %%
col_miss = []
for col in df_month.columns:
    if df_month[col].isnull().sum():
        col_miss.append(col)
        print(col, ": ", df_month[col].isnull().sum())

# %%
df_year.interpolate(method="linear", axis=1, inplace = True)
df_month.interpolate(method="linear", axis=1, inplace = True)

# %%
col_miss_year = []
for col in df.columns:
    if df[col].isnull().sum():
        col_miss.append(col)
        print(col, ": ", df[col].isnull().sum())
col_miss = []
for col in df.columns:
    if df[col].isnull().sum():
        col_miss.append(col)
        print(col, ": ", df[col].isnull().sum())

# %%
df_year = pd.read_csv("data\\cleaned\\data_yearly_cleaned.csv", index_col="date", parse_dates=["date"])
df_month = pd.read_csv("data\\cleaned\\data_monthly_cleaned.csv", index_col="date", parse_dates=["date"])

# %%
df_year.describe()

# %%
df_year = df_year.sort_values(by="date")
df_year

# %%
# %matplotlib inline
df_year.plot(use_index=True, y=["f_rf", "f_ind_M10_P"])
